# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
progress_df = pd.read_csv("results/classifiers_proj/compose_contrast_double_proj3/progress.csv")
# progress_df = pd.read_csv("results/classifiers_proj/compose_contrast_double_proj/progress.csv")

start = 10
train_loss = list(progress_df["train_loss"])[start:]
val_loss = list(progress_df["val_loss"])[start:]
steps = list(progress_df["step"])[start:]

progress_df
# Out:
#     step  train_loss  val_loss
# 0      0    3.843588  3.665970
# 1    500    1.810465  2.191747
# 2   1000    1.225813  2.225536
# 3   1500    1.086814  1.473485
# 4   2000    0.989112  1.612907
# 5   2500    0.876478  1.131074
# 6   3000    0.838635  0.906716
# 7   3500    0.819423  1.084867
# 8   4000    0.787248  1.354089
# 9   4500    0.749440  0.808547
# 10  5000    0.711319  0.840544
# 11  5500    0.696397  0.777333
# 12  6000    0.690869  0.765303
# 13  6500    0.704716  0.712547
# 14  7000    0.681554  0.655755

# %%
plt.plot(steps, train_loss, label="train_loss")
plt.plot(steps, val_loss, label="val_loss")
plt.xlabel("steps")
plt.ylabel("loss")
plt.legend()
plt.show()
