# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
progress_df = pd.read_csv("results/encoders_proj/compose_contrast_double/checkpoint_progress.csv")
# progress_df = pd.read_csv("results/encoders/compose_contrast_double/checkpoint_progress.csv")

train_loss = list(progress_df["train_loss"])
val_loss = list(progress_df["val_loss"])
steps = list(progress_df["step"])

progress_df
# Out:
#      step  train_loss  val_loss
# 0       0    4.948739  4.836807
# 1    1000    4.647833  4.630262
# 2    2000    4.606002  4.610179
# 3    3000    4.585378  4.606276
# 4    4000    4.577780  4.565072
# 5    5000    4.562682  4.575357
# 6    6000    4.563751  4.567681
# 7    7000    4.553389  4.563059
# 8    8000    4.557010  4.553089
# 9    9000    4.548997  4.541836
# 10  10000    4.546841  4.541824

# %%
plt.plot(steps, train_loss, label="train_loss")
plt.plot(steps, val_loss, label="val_loss")
plt.xlabel("steps")
plt.ylabel("loss")
plt.legend()
plt.show()
